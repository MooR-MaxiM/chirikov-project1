# %%
import pandas as pd

# %%
df_samz_all = pd.read_excel('C://Users//m.chirikov//Downloads//Pandas_данные_для_курса//210923//натест//44фз.общий файл.xlsx')

# %%
df_samz_all
# Out:
#       Дата размещения первой версии извещения      НмЦК     Извещение (URL)  \
# 0                                  2023-09-20      4901  325300015223000129
# 1                                  2023-09-20      4901  325300015223000129
# 2                                  2023-09-20      6894  321200030023000115
# 3                                  2023-09-20      6894  321200030023000115
# 4                                  2023-09-20      6894  321200030023000115
# ...                                       ...       ...                 ...
# 25542                              2023-01-10  64648000  105500000223000001
# 25543                              2023-01-10  78061000  105500000223000003
# 25544                              2023-01-09     56269  525600002423000002
# 25545                              2023-01-09     56269  525600002423000002
# 25546                              2023-01-09     56269  525600002423000002
#
#       ОКПД 2. Код подкатегории (7-ой уровень)  \
# ...

# %%
df_kalm=df_samz_all[(df_samz_all['Наименование субъекта РФ заказчика'].isin(['Астраханская область','Волгоградская область','Кабардино-Балкарская Республика','Республика Ингушетия','Республика Калмыкия','Республика Северная Осетия-Алания','Ставропольский край','Чеченская Республика']))&(df_samz_all['ОКПД 2. Код подкатегории (7-ой уровень)'].str.startswith(('01.6','02.40.10.120','81.22.12','38.21','13.9','16.2','10.1','10.71','25.99.2','41.20.40','31.01', '31.03','31.09','01.13.3','01.19.1','01.42','01.43.1','01.45.1','01.46.1','01.61','46.32','01.47','16.24')))]
#df_penza=df_samz_all[(df_samz_all['Наименование субъекта РФ заказчика'].isin(['Пензенская область','Ульяновская область','Республика Мордовия','Саратовская область']))&(df_samz_all['ОКПД 2. Код подкатегории (7-ой уровень)'].str.startswith(('01.6','02.40.10.120','81.22.12','38.21','13.9','16.2','10.1','10.71','25.99.2','41.20.40','31.01', '31.03','31.09','01.13.3','01.19.1','01.42','01.43.1','01.45.1','01.46.1','01.61','46.32','01.47','16.24')))]
df_vlad=df_samz_all[(df_samz_all['Наименование субъекта РФ заказчика']=='Владимирская область')&(df_samz_all['ОКПД 2. Код подкатегории (7-ой уровень)'].str.startswith(('13.92.11','13.92.12.110','13.92.12.130','13.92.14.110','13.92.14.120','13.92.24.110','13.92.24.140','13.92.24.150','14.12.11.110','14.12.11.120','14.12.11.130','14.12.12.110','14.12.12.120','14.12.21.110','14.12.21.120','14.12.21.130','14.12.22.110','14.12.22.120','14.12.99.200','14.14.30.110','14.14.30.120','14.14.99.200','15.12.11.120','15.12.12.210','15.20.32.122','15.20.32.123','15.20.32.125','16.24.13.110','25.29.11.900','25.72.12.110','25.72.12.120','25.99.21.112','25.99.21.114','25.99.99.219','31.01','31.02','31.03.12.120','31.09.11.110','31.09.11.120','31.09.11.130','31.09.12','31.09.13.140','31.09.13.144','31.09.91.111','31.09.91.120','31.09.99.213','31.09.99.214','31.09.99.215','32.30.14.110','32.30.14.113','32.30.14.114','32.30.14.117','32.30.14.120','32.30.15.230','32.30.15.231','32.30.15.232','32.40.42.191','32.40.42.192','42.11.10.130')))]
df_sar=df_samz_all[(df_samz_all['Наименование субъекта РФ заказчика']=='Саратовская область')&(df_samz_all['ОКПД 2. Код подкатегории (7-ой уровень)'].str.startswith(('10.73.11.110','13.92.11','13.92.12','13.92.21','13.92.24','14.14.1','14.14.30','14.14.9','16.10.10','16.23','16.24.1','22.23.14','23.6','25.11','25.12.10','25.29.11','25.93.13','27.51.24.170','28.93.17.120','31.01','31.09.11.110','31.09.11.190','42.11.10.130','42.99.12')))]

# %%
df_vlad
# Out:
#       Дата размещения первой версии извещения    НмЦК     Извещение (URL)  \
# 196                                2023-09-18   44764  328300056923000004
# 228                                2023-09-18  211025  128100000123000023
# 229                                2023-09-18  211025  128100000123000023
# 230                                2023-09-18  211025  128100000123000023
# 231                                2023-09-18  211025  128100000123000023
# ...                                       ...     ...                 ...
# 24735                              2023-01-26    9467  328300068923000017
# 25252                              2023-01-20  351923  328300032823000010
# 25448                              2023-01-17   42293  328300068923000002
# 25449                              2023-01-17   42293  328300068923000002
# 25450                              2023-01-17   42293  328300068923000002
#
#       ОКПД 2. Код подкатегории (7-ой уровень)  \
# ...

# %%
df_kalm.to_excel(r'C://Users//m.chirikov//Downloads//Pandas_данные_для_курса//210923//натест//44фз.20_09_23_Республика_Калмыкия.xlsx')
df_vlad.to_excel(r'C://Users//m.chirikov//Downloads//Pandas_данные_для_курса//210923//натест//44фз.20_09_23_Владимирская_область.xlsx')
#df_penza.to_excel(r'C://Users//m.chirikov//Downloads//Pandas_данные_для_курса//210923//натест//44фз.20_09_23_Пензенская_область.xlsx')
#df_sar.to_excel(r'C://Users//m.chirikov//Downloads//Pandas_данные_для_курса//210923//натест//44фз.20_09_23_Саратовская_область.xlsx')
